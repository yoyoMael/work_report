# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('recall_comp.csv')


values = df[df.columns[1:]].values
clf_names = df.columns[1:]
print(values)
# Out:
# [[0.893255 0.99738  0.832351 0.712508 0.996726 0.99738 ]
#  [0.834821 0.965774 0.920387 0.24464  0.964286 0.957589]
#  [0.850048 0.962751 0.728749 0.330468 0.968481 0.947469]
#  [0.964502 0.999245 0.953927 0.906344 0.999245 1.      ]
#  [0.854671 1.       0.903114 0.3212   1.       1.      ]
#  [0.892086 0.929496 0.991367 0.1416   0.995683 0.995683]
#  [0.919192 0.962963 0.690236 0.1322   0.959596 0.952862]
#  [0.149153 0.989831 0.277966 0.203    0.979661 0.989831]]

# %%
fig = plt.figure(figsize=(12,8))

width = .35
index = np.arange(len(clf_names))
classes = ['FTP-C','FTP-P','P2P','DATABASE']
for i in range(4):
    ax = plt.subplot(2,2,i+1)
    rects1 = ax.bar(clf_names,values[i],align='center',width=width,
       color=(.3,.6,.6,.5),edgecolor='w',linewidth=1,log=False,label='test 1')
    rects2 = ax.bar(index+width,values[i+4], align='center',width=width,
       color=(.2,.5,.6,1),edgecolor='w',linewidth=1,log=False,label='test 2')
    ax.set_ylabel('Recall')
    plt.title(classes[i])
plt.xticks(index+width/2,clf_names)
def set_values(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2, height, height, ha='center', va='bottom',fontsize=8)
        rect.set_edgecolor((.9,.9,1))
# add values on the top of the bar

fig.legend(['Test1','Test2'])

plt.savefig('minor_comp.png')
# from matplotlib.ticker import MultipleLocator, FormatStrFormatter, NullLocator
# yformatter = FormatStrFormatter('%1.2f')
# ylocator = NullLocator()
# ax.yaxis.set_major_formatter(ymajorLocator)
# ax.yaxis.set_major_locator(ylocator)

# set_values(rects1)
# set_values(rects2)
